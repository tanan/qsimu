# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ptick
import numpy as np

## ising(order by time asc)
bn_depth_12 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_12_10.0_False_False_True_cost.txt")
bn_depth_18 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_18_10.0_False_False_True_cost.txt")
bn_depth_24 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_24_10.0_False_False_True_cost.txt")
bn_depth_30 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_30_10.0_False_False_True_cost.txt")
bn_depth_36 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_36_10.0_False_False_True_cost.txt")
bn_depth_42 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_42_10.0_False_False_True_cost.txt")

depth_12 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_12_10.0_False_False_False_cost.txt")
depth_18 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_18_10.0_False_False_False_cost.txt")
depth_24 = np.loadtxt("./6qubit_indirect_by_ising_hamiltonian_24_10.0_False_False_False_cost.txt")

plt.figure(figsize=(12,8))
plt.rcParams["font.size"] = 14
plt.plot(bn_depth_12, color="red", label="bn_depth=12")
plt.plot(bn_depth_18, color="red", label="bn_depth=18")
plt.plot(bn_depth_24, color="red", label="bn_depth=24")
plt.plot(bn_depth_30, color="red", label="bn_depth=30")
plt.plot(bn_depth_36, color="red", label="bn_depth=36")
plt.plot(depth_12, color="blue", label="depth=36")
plt.plot(depth_18, color="blue", label="depth=18")
plt.plot(depth_24, color="blue", label="depth=24")

plt.xlabel("Iteration")
plt.ylabel("Energy expectation value")
plt.legend()
plt.show()

# %%
## xy model
depth_6 = np.loadtxt("./6qubit_indirect_by_xy_hamiltonian_6_10.0_False_False_False_cost.txt")
depth_12 = np.loadtxt("./6qubit_indirect_by_xy_hamiltonian_12_10.0_False_False_False_cost.txt")
depth_18 = np.loadtxt("./6qubit_indirect_by_xy_hamiltonian_18_10.0_False_False_False_cost.txt")

bn_depth_6 = np.loadtxt("./6qubit_indirect_by_xy_hamiltonian_6_10.0_False_False_True_cost.txt")
# bn_depth_12 = np.loadtxt("./6qubit_indirect_by_xy_hamiltonian_12_10.0_False_False_True_cost.txt")
# bn_depth_18 = np.loadtxt("./6qubit_indirect_by_xy_hamiltonian_18_10.0_False_False_True_cost.txt")

plt.figure(figsize=(12,8))
plt.rcParams["font.size"] = 14
plt.plot(depth_6, color="red", label="depth=6")
plt.plot(depth_12, color="orange", label="depth=12")
plt.plot(depth_18, color="blue", label="depth=18")
plt.plot(bn_depth_6, color="green", label="bn_depth=6")
# plt.plot(bn_depth_12, color="orange", label="bn_depth=12")
# plt.plot(bn_depth_18, color="blue", label="bn_depth=18")
plt.xlabel("Iteration")
plt.ylabel("Energy expectation value")
plt.legend()
plt.show()

# %%
## xyz model
depth_18 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_18_10.0_False_False_False_cost.txt")
depth_24 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_24_10.0_False_False_False_cost.txt")
depth_30 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_30_10.0_False_False_False_cost.txt")
depth_36 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_36_10.0_False_False_False_cost.txt")

plt.figure(figsize=(12,8))
plt.rcParams["font.size"] = 14
plt.plot(depth_18, color="red", label="depth=18")
plt.plot(depth_24, color="orange", label="depth=24")
plt.plot(depth_30, color="blue", label="depth=30")
plt.plot(depth_36, color="black", label="depth=36")
plt.xlabel("Iteration")
plt.ylabel("Energy expectation value")
plt.legend()
plt.show()

# %%
## xyz model(depth=4)
time_5 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_5.0_False_False_False_cost.txt")
time_4 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_4.0_False_False_False_cost.txt")
time_3 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_3.0_False_False_False_cost.txt")
time_2 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_2.0_False_False_False_cost.txt")
time_1 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_1.0_False_False_False_cost.txt")
time_01 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_0.1_False_False_False_cost.txt")
time_001 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_0.01_False_False_False_cost.txt")
time_0001 = np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_0.001_False_False_False_cost.txt")

plt.figure(figsize=(12,8))
plt.rcParams["font.size"] = 14
plt.plot(time_5, color="red", label="time=5")
plt.plot(time_4, color="orange", label="time=4")
plt.plot(time_3, color="blue", label="time=3")
plt.plot(time_2, color="black", label="time=2")
plt.plot(time_1, color="green", label="time=1")
plt.plot(time_01, color="gray", label="time=0.1")
plt.plot(time_001, color="purple", label="time=0.01")
plt.plot(time_0001, color="pink", label="time=0.001")
plt.xlabel("Iteration")
plt.ylabel("Energy expectation value")
plt.legend()
plt.show()

# %%
## ハミルトニアンゲートの時間発展を短時間にした場合
## xyz model(depth=4)
depth_4 = np.array([])
depth_4 = np.append(depth_4, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_5.0_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_4.0_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_3.0_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_2.0_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_1.0_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_0.1_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_0.01_False_False_False_cost.txt")[-1])
depth_4 = np.append(depth_4,np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_4_0.001_False_False_False_cost.txt")[-1])

depth_8 = np.array([])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_5.0_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_4.0_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_3.0_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_2.0_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_1.0_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_0.1_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_0.01_False_False_False_cost.txt")[-1])
depth_8 = np.append(depth_8, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_8_0.001_False_False_False_cost.txt")[-1])

depth_10 = np.array([])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_5.0_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_4.0_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_3.0_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_2.0_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_1.0_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_0.1_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_0.01_False_False_False_cost.txt")[-1])
depth_10 = np.append(depth_10, np.loadtxt("./6qubit_indirect_by_xyz_hamiltonian_10_0.001_False_False_False_cost.txt")[-1])

x = np.array([5, 4, 3, 2, 1, 0.1, 0.01, 0.001])

plt.figure(figsize=(12,8))
plt.rcParams["font.size"] = 14
plt.plot(x, depth_4, color="red", label="depth=4")
plt.plot(x, depth_8, color="orange", label="depth=8")
plt.plot(x, depth_10, color="pink", label="depth=10")
plt.xlabel("time")
plt.ylabel("Energy expectation value")
plt.xscale("log")
# plt.ticklabel_format(style='sci',axis='x',scilimits=(0,0))
plt.legend()
plt.show()
